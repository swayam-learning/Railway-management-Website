# %% [markdown]
# This is project is submitted by Rahul chand and Swayam swarup barik , this is a project on railway management system where we provide information about the train routes between Mumbai ,Delhi,Vijaywadah,Howrah ,where we provide information about the arrival time ,departure time and the train number along with the train name.<br>
# ere the user has to provide the information about the starting point and ending point and then the list of information will displayed ,<br>
# Refering to that information the user has to choose which train number he/she wants to travel .<br>
# we have also provided the choice of seats and their base prices according to the latest data including gst and cancellation fees.<br>
# we have dispalyed only four direct trains along with all of their information.

# %%
print("Enter your locations Howrah,Delhi,Mumbai,Vijaywadah")
start=input("Enter your starting point: ")
stop=input("Enter your Destination: ")
if(start=="Delhi" or start=="delhi") and (stop=="Mumbai" or stop=="mumbai"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("4:00".ljust(20)+"23:35".ljust(20)+"golden temple m".ljust(20)+"12904".ljust(20))
    print("6:16".ljust(20)+"23:00".ljust(20)+"TVC Rajdhani".ljust(20)+"12432".ljust(20))
    print("16:35".ljust(20)+"15:25".ljust(20)+"Paschim Express".ljust(20)+"12926".ljust(20))
    print("21:40".ljust(20)+"16:10".ljust(20)+"Swaraj Express".ljust(20)+"12472".ljust(20))
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12904) and stp=="1-tier":
        bprice=3955.00
        bp=input("enter your berth preference U or  L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12904) and stp=="2-tier":
        bprice=2335.00
        bp=input("Enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12904) and stp=="3-tier":
        bprice=1630.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12904) and stp=="sleeper":
        bprice=565.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
## this is second train
    if(trn==12432) and stp=="1-tier":
        print("Sorry Not Available: ")
    if(trn==12432) and stp=="2-tier":
        bprice=5679.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12432) and stp=="3-tier":
        bprice=3862.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12904) and stp=="sleeper":
        print("Sorry Not Available")
# this is third train
    if(trn==12926) and stp=="1-tier":
        print("Sorry Not Available ")
    if(trn==12926) and stp=="2-tier":
        bprice=2305.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12926) and stp=="3-tier":
        bprice=1610.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12926) and stp=="sleeper":
        bprice=560.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
#this is fourth train
    if(trn==12472) and stp=="1-tier":
        bprice=3955.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12472) and stp=="2-tier":
        bprice=2305.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12472) and stp=="3-tier":
        bprice=1610.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12472) and stp=="sleeper":
        bprice=615.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Delhi" or start=="delhi") and (stop=="Howrah" or stop=="howrah"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("16:30".ljust(20)+"10:10".ljust(20)+"Sealdah Rajdhani".ljust(20)+"12314".ljust(20))
    print("16:50".ljust(20)+"9:55".ljust(20)+"HWH Rajdhani".ljust(20)+"12302".ljust(20))
    print("17:40".ljust(20)+"17:00".ljust(20)+"Poorva Express ".ljust(20)+"12304".ljust(20)) 
    print("20:40".ljust(20)+"16:35".ljust(20)+"Sampark k Express".ljust(20)+"12330".ljust(20))
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12314) and stp=="1-tier":
        bprice=4650.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12314) and stp=="2-tier":
        bprice=3770.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12314) and stp=="3-tier":
        bprice=2636.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12314) and stp=="sleeper":
        print("Itna paisa chati mai leke jaoge kya")      
## this is second train
    if(trn==12302) and stp=="1-tier":
        bprice=4595.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12302) and stp=="2-tier":
        bprice=3736.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12302) and stp=="3-tier":
        bprice=2618.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12302) and stp=="sleeper":
        bprice=680.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==12304) and stp=="1-tier":
        bprice=4230.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12304) and stp=="2-tier":
        bprice=2490.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12304) and stp=="3-tier":
        bprice=1735.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12304) and stp=="sleeper":
        bprice=665.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
#this is fourth train
    if(trn==12330) and stp=="1-tier":
        bprice=4045.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12330) and stp=="2-tier":
        bprice=2910.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12330) and stp=="3-tier":
        bprice=1665.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12330) and stp=="sleeper":
        bprice=635.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Delhi" or start=="delhi") and (stop=="Vijaywadah" or stop=="vijaywadah"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("14:00".ljust(20)+"20:40".ljust(20)+"Andaman Express".ljust(20)+"16032".ljust(20))
    print("15:35".ljust(20)+"14:20".ljust(20)+"NZM Mas Rajdhani".ljust(20)+"12434".ljust(20))
    print("16:10".ljust(20)+"21:30".ljust(20)+"Grand Trunk Express".ljust(20)+"12616".ljust(20)) 
    print("20:10".ljust(20)+"12:20".ljust(20)+"Kerala Express".ljust(20)+"12626".ljust(20))
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==16032) and stp=="1-tier":
      print("Itna ameer kyun hain be tu")
    if(trn==16032) and stp=="2-tier":
        bprice=2680.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==16032) and stp=="3-tier":
        bprice=1845.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==16032) and stp=="sleeper":
        bprice=695.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==12434) and stp=="1-tier":
        bprice=6615.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12434) and stp=="2-tier":
        bprice=4843.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12434) and stp=="3-tier":
        bprice=3346.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12434) and stp=="sleeper":
       print("Sorry Not Available")
# this is third train
    if(trn==12616) and stp=="1-tier":
        bprice=4640.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12616) and stp=="2-tier":
        bprice=2725.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12616) and stp=="3-tier":
        bprice=1895.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12616) and stp=="sleeper":
        bprice=925.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
#this is fourth train
    if(trn==12626) and stp=="1-tier":
        bprice=3135.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12626) and stp=="2-tier":
        bprice=2465.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12626) and stp=="3-tier":
        bprice=1895.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12626) and stp=="sleeper":
        bprice=725.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Mumbai" or start=="mumbai") and (stop=="Delhi" or stop=="delhi"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("0:05".ljust(20)+"2:30".ljust(20)+"BDTS HW Exp".ljust(20)+"19019".ljust(20))
    print("12:15".ljust(20)+"11:35".ljust(20)+"BDTS DEE SFAST".ljust(20)+"22949".ljust(20))
    print("17:10".ljust(20)+"9:43".ljust(20)+"MMCT NZM AK Rajdhani".ljust(20)+"12953".ljust(20)) 
    print("19:35".ljust(20)+"21:35".ljust(20)+"Mumbai Mail".ljust(20)+"12626".ljust(20))
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==19019) and stp=="1-tier":
        bprice=3835.00
        bp=input("enter your berth preference U or  L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==19019) and stp=="2-tier":
        bprice=2040.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==19019) and stp=="3-tier":
        bprice=1585.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==19019) and stp=="sleeper":
        bprice=575.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==22949) and stp=="1-tier":
        bprice=3960.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==22949) and stp=="2-tier":
        bprice=2280.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==22949) and stp=="3-tier":
        bprice=1595.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12434) and stp=="sleeper":
       print("Sorry Not Available")
# this is third train
    if(trn==12953) and stp=="1-tier":
      print("Sorry Not Available")
    if(trn==12953) and stp=="2-tier":
        bprice=3575.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12953) and stp=="3-tier":
        bprice=3085.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12953) and stp=="sleeper":
      print("Sorry Not Available")
#this is fourth train
    if(trn==12137) and stp=="1-tier":
        bprice=4275.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12137) and stp=="2-tier":
        bprice=2280.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12137) and stp=="3-tier":
        bprice=1590.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12137) and stp=="sleeper":
        bprice=700.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Mumbai" or start=="mumbai") and (stop=="Howrah" or stop=="howrah"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("6:00".ljust(20)+"12:30".ljust(20)+"GITANJALI Exp".ljust(20)+"12859".ljust(20))
    print("17:15".ljust(20)+"20:15".ljust(20)+"Howrah Duronto".ljust(20)+"12261".ljust(20))
    print("22:00".ljust(20)+"11:35".ljust(20)+"LTT Shalimar Exp".ljust(20)+"18029".ljust(20)) 
    print("22:15".ljust(20)+"11:40".ljust(20)+"Kolkata Mail".ljust(20)+"12322".ljust(20))
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12859) and stp=="1-tier":
      print("Seat Not Available")
    if(trn==12859) and stp=="2-tier":
        bprice=2935.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12859) and stp=="3-tier":
        bprice=2035.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12859) and stp=="sleeper":
        bprice=780.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==12261) and stp=="1-tier":
        bprice=6625.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12261) and stp=="2-tier":
        bprice=4985.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12261) and stp=="3-tier":
        bprice=3615.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12261) and stp=="sleeper":
       print("Sorry Not Available")
# this is third train
    if(trn==18029) and stp=="1-tier":
      print("Seat Not Available")
    if(trn==18029) and stp=="2-tier":
        bprice=2865.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18029) and stp=="3-tier":
        bprice=1970.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18029) and stp=="sleeper":
        bprice=740.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
#this is fourth train
    if(trn==12322) and stp=="1-tier":
        bprice=5260.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12322) and stp=="2-tier":
        bprice=3080.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12322) and stp=="3-tier":
        bprice=2160.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12322) and stp=="sleeper":
        bprice=820.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Mumbai" or start=="mumbai") and (stop=="Vijaywadah" or stop=="vijaywadah"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("6:55".ljust(20)+"14:30".ljust(20)+"LTT VSKP  Exp".ljust(20)+"18520".ljust(20))
    print("13:20".ljust(20)+"9:25".ljust(20)+"LTT COA Exp".ljust(20)+"17222".ljust(20))
    print("14:00".ljust(20)+"9:25".ljust(20)+"Konark Express".ljust(20)+"11019".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==18520) and stp=="1-tier":
        bprice=4060.00
        bp=input("enter your berth preference U  or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18520) and stp=="2-tier":
        bprice=2935.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18520) and stp=="3-tier":
        bprice=1490.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18520) and stp=="sleeper":
        bprice=560.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==17222) and stp=="1-tier":
        bprice=3455.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==17222) and stp=="2-tier":
        bprice=2045.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==17222) and stp=="3-tier":
        bprice=1435.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==17222) and stp=="sleeper":
        bprice=550.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==11019) and stp=="1-tier":
      print("Seat Not Available")
    if(trn==11019) and stp=="2-tier":
        bprice=2025.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==11019) and stp=="3-tier":
        bprice=1405.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==11019) and stp=="sleeper":
        bprice=525.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="vijaywadah" or start=="Vijaywadah") and (stop=="Delhi" or stop=="Delhi"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("3:45".ljust(20)+"5:40".ljust(20)+"AP Exp".ljust(20)+"20805".ljust(20))
    print("3:55".ljust(20)+"6:30".ljust(20)+"Tamil nadu express".ljust(20)+"12621".ljust(20))
    print("15:15".ljust(20)+"20:55".ljust(20)+"TES DKEXP".ljust(20)+"16787".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==20805) and stp=="1-tier":
        bprice=4640.00
        bp=input("enter your berth preference U  or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==20805) and stp=="2-tier":
        bprice=2725.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==20805) and stp=="3-tier":
        bprice=1895.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==20805) and stp=="sleeper":
        bprice=655.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==12621) and stp=="1-tier":
        bprice=4640.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12621) and stp=="2-tier":
        bprice=2725.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12621) and stp=="3-tier":
        bprice=1895.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12621) and stp=="sleeper":
        bprice=695.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==16787) and stp=="1-tier":
        bprice=4655.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==16787) and stp=="2-tier":
        bprice=2680.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==16787) and stp=="3-tier":
        bprice=1845.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==16787) and stp=="sleeper":
        bprice=695.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="vijaywadah" or start=="Vijaywadah") and (stop=="Mumbai" or stop=="mumbai"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("4:55".ljust(20)+"4:00".ljust(20)+"KNARK EXP".ljust(20)+"11020".ljust(20))
    print("7:00".ljust(20)+"4:15".ljust(20)+"VSKP LTT EXP".ljust(20)+"18519".ljust(20))
    print("12:50".ljust(20)+"11:00".ljust(20)+"COA LTT EXP".ljust(20)+"17221".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==11020) and stp=="1-tier":
       print("Seat Not Available")
    if(trn==11020) and stp=="2-tier":
        bprice=2025.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==11020) and stp=="3-tier":
        bprice=1405.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==11020) and stp=="sleeper":
        bprice=525.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==18519) and stp=="1-tier":
        bprice=3375.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18519) and stp=="2-tier":
        bprice=1995.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18519) and stp=="3-tier":
        bprice=1385.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18519) and stp=="sleeper":
        bprice=520.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==17221) and stp=="1-tier":
        bprice=3005.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==17221) and stp=="2-tier":
        bprice=2495.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==17221) and stp=="3-tier":
        bprice=1370.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==17721) and stp=="sleeper":
        bprice=510.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="vijaywadah" or start=="Vijaywadah") and (stop=="Howrah" or stop=="howrah"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("1:30".ljust(20)+"23:00".ljust(20)+"MAS HWH MAIL".ljust(20)+"12840".ljust(20))
    print("2:05".ljust(20)+"23:55".ljust(20)+"TPJ HWH EXP".ljust(20)+"12664".ljust(20))
    print("13:30".ljust(20)+"23:55".ljust(20)+"COROMANDEL EXP".ljust(20)+"12842".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12840) and stp=="1-tier":
        bprice=3680.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12840) and stp=="2-tier":
        bprice=2175.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12840) and stp=="3-tier":
        bprice=1945.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12840) and stp=="sleeper":
        bprice=580.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
        
## this is second train
    if(trn==12664) and stp=="1-tier":
        bprice=3680.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12664) and stp=="2-tier":
        bprice=1970.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12664) and stp=="3-tier":
        bprice=1525.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12664) and stp=="sleeper":
        bprice=580.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==12842) and stp=="1-tier":
        bprice=3680.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12842) and stp=="2-tier":
        bprice=2175.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12842) and stp=="3-tier":
        bprice=1525.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12842) and stp=="sleeper":
        bprice=580.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Howrah" or start=="howrah") and (stop=="Vijaywadah" or stop=="vijaywadah"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("8:35".ljust(20)+"3:50".ljust(20)+"Falknuma  Exp".ljust(20)+"12703".ljust(20))
    print("10:50".ljust(20)+"4:05".ljust(20)+"SMVB DURONTO Exp".ljust(20)+"12245".ljust(20))
    print("11:20".ljust(20)+"10:25".ljust(20)+"EAST Coast Express".ljust(20)+"11019".ljust(20)) 
    print("15:20".ljust(20)+"9:55".ljust(20)+"Cormandal Express".ljust(20)+"12841".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12703) and stp=="1-tier":
        bprice=3680.00
        bp=input("enter your berth preference U  or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12703) and stp=="2-tier":
        bprice=2175.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12703) and stp=="3-tier":
        bprice=1525.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12703) and stp=="Sleeper":
        bprice=580.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
       ## this is second train
    if(trn==12245) and stp=="1-tier":
        bprice=4765.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12245) and stp=="2-tier":
        bprice=3825.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12245) and stp=="3-tier":
        bprice=1703.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12245) and stp=="Sleeper":
        bprice=862.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==18045) and stp=="1-tier":
      print("Seat Not Available")
    if(trn==18045) and stp=="2-tier":
        bprice=2130.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18045) and stp=="3-tier":
        bprice=1475.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18045) and stp=="sleeper":
        bprice=50.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190) 
   #this is fourth train
    if(trn==12841) and stp=="1-tier":
        bprice=3680.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12841) and stp=="2-tier":
        bprice=1970.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12841) and stp=="3-tier":
        bprice=1525.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12841) and stp=="Sleeper":
        bprice=580.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
if(start=="Howrah" or start=="howrah") and (stop=="Delhi" or stop=="delhi"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("8:00".ljust(20)+"6:00".ljust(20)+"Poorva  Exp".ljust(20)+"12303".ljust(20))
    print("13:10".ljust(20)+"8:40".ljust(20)+"Sampart K Exp".ljust(20)+"12329".ljust(20))
    print("16:50".ljust(20)+"10:05".ljust(20)+"Rajdhani Express".ljust(20)+"12301".ljust(20)) 
    print("21:55".ljust(20)+"21:25".ljust(20)+"Netaji Express".ljust(20)+"12841".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12303) and stp=="1-tier":
        bprice=3820.00
        bp=input("enter your berth preference U  or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12303) and stp=="2-tier":
        bprice=2490.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12303) and stp=="3-tier":
        bprice=1665.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12303) and stp=="Sleeper":
        bprice=635.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
       ## this is second train
    if(trn==12329) and stp=="1-tier":
        print("Seat Not Available")
    if(trn==12329) and stp=="2-tier":
        bprice=2385.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12329) and stp=="3-tier":
        bprice=1665.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12329) and stp=="sleeper":
        bprice=635.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==12301) and stp=="1-tier":
        bprice=4150.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12301) and stp=="2-tier":
        bprice=3736.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12301) and stp=="3-tier":
        bprice=2615.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12301) and stp=="sleeper":
        print("Seat Not Available") 
   #this is fourth train
    if(trn==12311) and stp=="1-tier":
        bprice=4045.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12311) and stp=="2-tier":
        bprice=2385.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12311) and stp=="3-tier":
        bprice=1665.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12311) and stp=="sleeper":
        bprice=635.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)

# %%
if(start=="Howrah" or start=="howrah") and (stop=="Mumbai" or stop=="mumbai"):
    print("Train departure".ljust(20)+"Train arrival".ljust(20)+"Train name".ljust(20)+"Train no.".ljust(20))
    print("5:45".ljust(20)+"8:00".ljust(20)+"CSMT DURONTO  Exp".ljust(20)+"12262".ljust(20))
    print("15:30".ljust(20)+"4:05".ljust(20)+"SHM LTT Exp".ljust(20)+"18030".ljust(20))
    print("19:50".ljust(20)+"4:25".ljust(20)+"HWH CSMT Express".ljust(20)+"12810".ljust(20)) 
    print("23:35".ljust(20)+"13:10".ljust(20)+"Mumbai Mail Express".ljust(20)+"12321".ljust(20)) 
    trn=float(input("Enter your train number: "))
    stp=(input("Enter your coach preferrence 3-tier or 2-tier or 1-tier or sleeper:"))
    if(trn==12262) and stp=="1-tier":
        bprice=5680.00
        bp=input("enter your berth preference U  or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12262) and stp=="2-tier":
        bprice=4593.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12262) and stp=="3-tier":
        bprice=2850.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12262) and stp=="sleeper":
        bprice=620.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
       ## this is second train
    if(trn==18030) and stp=="1-tier":
        print("Seat Not Available")
    if(trn==18030) and stp=="2-tier":
        bprice=2865.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18030) and stp=="3-tier":
        bprice=1970.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==18030) and stp=="sleeper":
        bprice=740.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
# this is third train
    if(trn==12810) and stp=="1-tier":
        bprice=5005.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12810) and stp=="2-tier":
        bprice=3125.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12810) and stp=="3-tier":
        bprice=2035.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12810) and stp=="sleeper":
        print("Tu rhan de bhai") 
   #this is fourth train
    if(trn==12321) and stp=="1-tier":
        bprice=5260.00
        bp=input("enter your berth preference U or L :")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12321) and stp=="2-tier":
        bprice=3080.00
        bp=input("enter your berth preference U or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12321) and stp=="3-tier":
        bprice=2130.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
    if(trn==12321) and stp=="sleeper":
        bprice=820.00
        bp=input("enter your berth preference U or M or L or SU or SL:")
        if(bp=="U"):
            ("Your seat allocated is upper")
        if(bp=="L"):
            ("Your seat allocated is Lower")
        if(bp=="M"):
            ("Your seat allocated is Middle")
        if(bp=="SU"):
            ("Your seat allocated is Side Upper")
        if(bp=="SL"):
            ("Your seat allocated is Side Lower")
        print("Your total price including GST and Cancellation: ",bprice+190)
